# %%
import numpy as np
import imageio
import matplotlib.pyplot as plt
label_dir = '../../data/sim_labels/'
def rgb2gray(rgb):

    r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
    gray = 0.2989 * r + 0.5870 * g + 0.1140 * b

    return gray

# %%
# testing for data loader
from imitation_learning_dataloader import ImitationDataLoader

video_list = ['wd2_brown',
              'wd2_city1',
              'wd2_city2',
              'wd2_office',
              'wd2_park1',
              'wd2_park2',
              'wd2_sub']
imitation_dataset = ImitationDataLoader(video_name_list=video_list,batch_size=128)

# %%
length = 0
for batch in imitation_dataset:
    print(len(batch))
    print(batch[1])
    length += 1
print(length)
# Out:
# 2
# tensor([[0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.2500, 1.0000, 0.0000],
#         [0.2500, 1.0000, 0.0000],
#         [0.2500, 1.0000, 0.0000],
#         [0.2500, 1.0000, 0.0000],
#         [0.2500, 1.0000, 0.0000],
#         [0.2500, 1.0000, 0.0000],
#         [0.5000, 1.0000, 0.0000],
#         [0.5000, 1.0000, 0.0000],
#         [0.5000, 1.0000, 0.0000],
#         [0.5000, 1.0000, 0.0000],
#         [0.5000, 1.0000, 0.0000],
#         [0.7500, 1.0000, 0.0000],
#         [0.7500, 1.0000, 0.0000],
#         [0.7500, 1.0000, 0.0000],
#         [0.7500, 1.0000, 0.0000],
#         [0.7500, 1.0000, 1.0000],
#         [0.7500, 1.0000, 1.0000],
#         [0.5000, 1.0000, 0.0000],
#         [0.5000, 1.0000, 0.0000],
#         [0.2500, 1.0000, 0.0000],
#         [0.2500, 1.0000, 0.0000],
#         [0.2500, 1.0000, 0.0000],
#         [0.2500, 1.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.2500, 1.0000, 0.0000],
#         [0.2500, 1.0000, 0.0000],
#         [0.2500, 1.0000, 0.0000],
#         [0.2500, 1.0000, 0.0000],
#         [0.2500, 1.0000, 0.0000],
#         [0.2500, 1.0000, 0.0000],
#         [0.5000, 1.0000, 1.0000],
#         [0.5000, 1.0000, 1.0000],
#         [0.5000, 1.0000, 1.0000],
#         [0.5000, 1.0000, 1.0000],
#         [0.5000, 1.0000, 1.0000],
#         [0.5000, 1.0000, 1.0000],
#         [0.5000, 1.0000, 1.0000],
#         [0.5000, 1.0000, 1.0000],
#         [0.5000, 1.0000, 1.0000],
#         [0.5000, 1.0000, 1.0000],
#         [0.5000, 1.0000, 0.0000],
#         [0.5000, 1.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000],
#         [0.5000, 1.0000, 0.0000],
#         [0.5000, 1.0000, 0.0000],
#         [0.5000, 1.0000, 0.0000],
#         [0.5000, 1.0000, 0.0000],
#         [0.5000, 1.0000, 0.0000],
#         [0.5000, 1.0000, 1.0000],
#         [0.5000, 1.0000, 1.0000],
#         [0.5000, 1.0000, 1.0000],
#         [0.5000, 1.0000, 1.0000],
#         [0.5000, 1.0000, 1.0000],
#         [0.5000, 1.0000, 1.0000],
#         [0.2500, 1.0000, 1.0000],
#         [0.2500, 1.0000, 1.0000],
#         [0.2500, 1.0000, 1.0000],
#         [0.2500, 1.0000, 1.0000],
#         [0.2500, 1.0000, 0.0000],
#         [0.2500, 1.0000, 0.0000],
#         [0.2500, 1.0000, 0.0000]])
# 1

# %%
# experiments with decord
import decord
from decord import VideoLoader
from decord import cpu, gpu
import matplotlib.pyplot as plt
decord.bridge.set_bridge('torch')
vl = VideoLoader(['../../data/sim_video_clips/vid_wd2_brown.mp4'], ctx=[cpu(0)], shape=(64,200,200,3), interval=0, skip=0, shuffle=1)
vl.reset()
print('Total batches:', len(vl))
for batch in vl:
    plt.imshow(batch[0][0])
    plt.show()
# Out:
# Total batches: 64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\PIL\ImageFile.py:515, in _save(im, fp, tile, bufsize)
#     514 try:
# --> 515     fh = fp.fileno()
#     516     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\qtcc\OneDrive\Desktop\Senior Project\Pizzair\drone_control\testing_notebook.ipynb Cell 4 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/qtcc/OneDrive/Desktop/Senior%20Project/Pizzair/drone_control/testing_notebook.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a> for batch in vl:
#      <a href='vscode-notebook-cell:/c%3A/Users/qtcc/OneDrive/Desktop/Senior%20Project/Pizzair/drone_control/testing_notebook.ipynb#W3sZmlsZQ%3D%3D?line=10'>11</a>     plt.imshow(batch[0][0])
# ---> <a href='vscode-notebook-cell:/c%3A/Users/qtcc/OneDrive/Desktop/Senior%20Project/Pizzair/drone_control/testing_notebook.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a>     plt.show()
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\matplotlib\pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# --> 446 return _get_backend_mod().show(*args, **kwargs)
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\IPython\core\display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\IPython\core\formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\IPython\core\formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\IPython\core\formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\matplotlib\backend_bases.py:2366, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2362 try:
#    2363     # _get_renderer may change the figure dpi (as vector formats
#    2364     # force the figure dpi to 72), so we need to set it again here.
#    2365     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2366         result = print_method(
#    2367             filename,
#    2368             facecolor=facecolor,
#    2369             edgecolor=edgecolor,
#    2370             orientation=orientation,
#    2371             bbox_inches_restore=_bbox_inches_restore,
#    2372             **kwargs)
#    2373 finally:
#    2374     if bbox_inches and restore_bbox:
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\matplotlib\backend_bases.py:2232, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2228     optional_kws = {  # Passed by print_figure for other renderers.
#    2229         "dpi", "facecolor", "edgecolor", "orientation",
#    2230         "bbox_inches_restore"}
#    2231     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2232     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2233         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2234 else:  # Let third-parties do as they see fit.
#    2235     print_method = meth
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\matplotlib\backends\backend_agg.py:509, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     462 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     463     """
#     464     Write the figure to a PNG file.
#     465
#    (...)
#     507         *metadata*, including the default 'Software' key.
#     508     """
# --> 509     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\matplotlib\backends\backend_agg.py:458, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     453 """
#     454 Draw the canvas, then save it using `.image.imsave` (to which
#     455 *pil_kwargs* and *metadata* are forwarded).
#     456 """
#     457 FigureCanvasAgg.draw(self)
# --> 458 mpl.image.imsave(
#     459     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\matplotlib\image.py:1689, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1687 pil_kwargs.setdefault("format", format)
#    1688 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1689 image.save(fname, **pil_kwargs)
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\PIL\Image.py:2413, in Image.save(self, fp, format, **params)
#    2410         fp = builtins.open(filename, "w+b")
#    2412 try:
# -> 2413     save_handler(self, fp, filename)
#    2414 except Exception:
#    2415     if open_fp:
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\PIL\PngImagePlugin.py:1398, in _save(im, fp, filename, chunk, save_all)
#    1396     _write_multiple_frames(im, fp, chunk, rawmode, default_image, append_images)
#    1397 else:
# -> 1398     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1400 if info:
#    1401     for info_chunk in info.chunks:
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\PIL\ImageFile.py:519, in _save(im, fp, tile, bufsize)
#     517     _encode_tile(im, fp, tile, bufsize, fh)
#     518 except (AttributeError, io.UnsupportedOperation) as exc:
# --> 519     _encode_tile(im, fp, tile, bufsize, None, exc)
#     520 if hasattr(fp, "flush"):
#     521     fp.flush()
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\PIL\ImageFile.py:538, in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     535 if exc:
#     536     # compress to Python file-compatible object
#     537     while True:
# --> 538         errcode, data = encoder.encode(bufsize)[1:]
#     539         fp.write(data)
#     540         if errcode:
#
# KeyboardInterrupt:

# %%
basic_iter = iter(range(3))
print(basic_iter.__next__())
print(basic_iter.__next__())
print(basic_iter.__next__())
try:
    print(basic_iter.__next__())
except:
    print('woof')
else:
    print('meow')
# Out:
# 0
# 1
# 2
# woof

# %%
vid = imageio.get_reader('../../data/sim_video_clips/vid_wd2_brown.mp4','ffmpeg')
i = 0
for frame in vid:
    i+=1
print(i)
# Out:
# 4132

# %%
frame,steer,safety = next(iter(imitation_train_dataloader))

# %%
thing = 0
for X_train_batch,Y_train_batch,other_thing in imitation_train_dataloader:
    print('woof')
    thing += 1
print(thing)
# Out:
# woof
# woof
# woof
# woof
# woof
# woof
# woof
# woof
# woof
# woof
# woof
# woof
# woof
# woof
# woof
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\qtcc\OneDrive\Desktop\Senior Project\Pizzair\drone_control\testing_notebook.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/qtcc/OneDrive/Desktop/Senior%20Project/Pizzair/drone_control/testing_notebook.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> thing = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/qtcc/OneDrive/Desktop/Senior%20Project/Pizzair/drone_control/testing_notebook.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> for X_train_batch,Y_train_batch,other_thing in imitation_train_dataloader:
#       <a href='vscode-notebook-cell:/c%3A/Users/qtcc/OneDrive/Desktop/Senior%20Project/Pizzair/drone_control/testing_notebook.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a>     print('woof')
#       <a href='vscode-notebook-cell:/c%3A/Users/qtcc/OneDrive/Desktop/Senior%20Project/Pizzair/drone_control/testing_notebook.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a>     thing += 1
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\torch\utils\data\dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\torch\utils\data\dataloader.py:674, in _SingleProcessDataLoaderIter._next_data(self)
#     672 def _next_data(self):
#     673     index = self._next_index()  # may raise StopIteration
# --> 674     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675     if self._pin_memory:
#     676         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\torch\utils\data\_utils\fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\torch\utils\data\_utils\fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File c:\Users\qtcc\OneDrive\Desktop\Senior Project\Pizzair\drone_control\imitation_learning_dataloader.py:51, in ImitationDataset.__getitem__(self, idx)
#      49 index_tuple = self.sample_to_video[idx]
#      50 vid_file_index, frame_index = index_tuple[0],index_tuple[1]
# ---> 51 frame = self.video_object_list[vid_file_index].get_data(frame_index)
#      52 #print(frame.shape)
#      53 frame = self.rgb2gray(frame)
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\imageio\core\format.py:435, in Format.Reader.get_data(self, index, **kwargs)
#     433 self._BaseReaderWriter_last_index = index
#     434 try:
# --> 435     im, meta = self._get_data(index, **kwargs)
#     436 except StopIteration:
#     437     raise IndexError(index)
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\imageio\plugins\ffmpeg.py:408, in FfmpegFormat.Reader._get_data(self, index)
#     406 else:
#     407     if (index < self._pos) or (index > self._pos + 100):
# --> 408         self._initialize(index)
#     409     else:
#     410         self._skip_frames(index - self._pos - 1)
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\imageio\plugins\ffmpeg.py:496, in FfmpegFormat.Reader._initialize(self, index)
#     494     self._meta.update(self._read_gen.__next__())
#     495 else:
# --> 496     self._read_gen.__next__()
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\imageio_ffmpeg\_io.py:291, in read_frames(path, pix_fmt, bpp, input_params, output_params, bits_per_pixel)
#     289 etime = time.time() + 10.0
#     290 while log_catcher.is_alive() and not log_catcher.header and time.time() < etime:
# --> 291     time.sleep(0.01)
#     293 # Check whether we have the information
#     294 if not log_catcher.header:
#
# KeyboardInterrupt:

# %%
print(frame.shape)
# Out:
# torch.Size([64, 720, 1280, 3])

# %%
print(len(np.load(label_dir+'label_steering_wd2_brown.npy')))
print(len(np.load(label_dir+'label_safety_wd2_brown.npy')))
# Out:
# 4132
# 4132

# %%
load_dir = '../../data/sim_video_clips/'
filename = 'vid_wd2_test.mp4'
vid = imageio.get_reader(load_dir + filename,'ffmpeg')
thing = vid.get_data(7)
thing = rgb2gray(thing)
plt.imshow(thing,cmap="gray")

# %%
# testing greyscale conversion 
import imageio
load_dir = '../../data/sim_video_clips/'
filename = 'vid_wd2_test.mp4'
vid = imageio.get_reader(load_dir + filename,'ffmpeg')
for frame in vid:
    frame = rgb2gray(frame)
    print(frame.shape)
# Out:
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
