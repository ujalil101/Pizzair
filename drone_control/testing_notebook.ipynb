# %%
import sys
sys.path.append('../flask_webapp/ReceivingData')
from path_test import hello
sys.path.pop(0)
sys.path.append('../flask_webapp/SendingData')
from path_test2 import hello2
hello()
hello2()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import sys
#       2 sys.path.append('../flask_webapp/ReceivingData')
# ----> 3 from path_test import hello
#       4 sys.path.pop(0)
#       5 sys.path.append('../flask_webapp/SendingData')
#
# ModuleNotFoundError: No module named 'path_test'

# %%
import numpy as np
np.random.rand()
# Out:
# 0.7301514074275003

# %%
import numpy as np
start_lat = 47.64146890761336
start_long = -122.14016549969952
tol_lat = 47.641498107619874
tol_long = -122.14016544830572
goal_lat =  47.64255048712882
goal_long = -122.14138240085241
print('Start -> Goal Distance:',np.sqrt((start_lat-goal_lat)**2 + (start_long-goal_long)**2))
print('Tolerance Distance:',np.sqrt((start_lat-tol_lat)**2 + (start_long-tol_long)**2))
# Out:
# Start -> Goal Distance: 0.0016280855825690137
# Tolerance Distance: 2.920005174392924e-05

# %%
-5 % 2
# Out:
# 1

# %%
import numpy as np
import imageio
import matplotlib.pyplot as plt
label_dir = '../../data/sim_labels/'

# %%
# testing for data loader
from imitation_learning_dataloader import ImitationDataLoader

video_list = ['wd2_brown',
              'wd2_city1',
              'wd2_city2',
              'wd2_office',
              'wd2_park1',
              'wd2_park2',
              'wd2_sub']
imitation_dataset = ImitationDataLoader(video_name_list=video_list,batch_size=1)

# %%
length = 0
import matplotlib.pyplot as plt
for batch in imitation_dataset:
    #print(len(batch))
    #print(batch[0].shape)
    print(batch[1:])
    plt.imshow(batch[0][0][0])
    length += 1
print(length)
# Out:
# torch.Size([1, 1, 216, 384])
# (tensor([[0., 1., 0.]]),)
# (tensor([[0., 1., 0.]]),)
# (tensor([[0., 1., 0.]]),)
# (tensor([[0., 1., 0.]]),)
# torch.Size([1, 1, 216, 384])
# (tensor([[0., 1., 0.]]),)
# (tensor([[0., 1., 0.]]),)
# (tensor([[0., 1., 0.]]),)
# (tensor([[0., 1., 0.]]),)
# torch.Size([1, 1, 216, 384])
# (tensor([[0., 1., 0.]]),)
# torch.Size([1, 1, 216, 384])
# (tensor([[0.7500, 0.0000, 0.0000]]),)
# torch.Size([1, 1, 216, 384])
# (tensor([[0., 1., 0.]]),)
# torch.Size([1, 1, 216, 384])
# (tensor([[1., 0., 0.]]),)
# torch.Size([1, 1, 216, 384])
# (tensor([[0., 1., 0.]]),)
# (tensor([[0., 1., 0.]]),)
# torch.Size([1, 1, 216, 384])
# (tensor([[0., 1., 0.]]),)
# (tensor([[0., 1., 0.]]),)
# (tensor([[0., 1., 0.]]),)
# (tensor([[0., 1., 0.]]),)
# (tensor([[0., 1., 0.]]),)
# (tensor([[1., 2., 0.]]),)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 7
# ...

# %%
print(imitation_dataset.__len__())
# Out:
# 234

# %%
imitation_dataset = ImitationDataLoader(video_name_list=video_list,batch_size=128,label_directory='meow')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 imitation_dataset = ImitationDataLoader(video_name_list=video_list,batch_size=128,label_directory='meow')
#
# File c:\Users\qtcc\OneDrive\Desktop\Senior Project\Pizzair\drone_control\imitation_learning_dataloader.py:40, in ImitationDataLoader.__init__(self, video_name_list, batch_size, video_directory, label_directory, video_size)
#      38 safety_labels = []
#      39 for video_file in video_name_list:
# ---> 40     safety_temp = np.load(label_directory + 'label_safety_'+video_file+'.npy')
#      41     safety_labels.append(safety_temp.tolist())
#      42 self.safety_labels = safety_labels
#
# File c:\Users\qtcc\miniconda3\envs\rl\Lib\site-packages\numpy\lib\npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# ...

# %%
# experiments with decord
import decord
from decord import VideoLoader
from decord import cpu, gpu
import matplotlib.pyplot as plt
decord.bridge.set_bridge('torch')
vl = VideoLoader(['../../data/sim_video_clips/vid_wd2_brown.mp4',
                  '../../data/sim_video_clips/vid_wd2_city1.mp4'],
                    ctx=[cpu(0)], shape=(64,200,200,3), interval=0, skip=0, shuffle=1)
vl.reset()
print('Total batches:', len(vl))
for batch in vl:
    plt.imshow(batch[0][0])
    plt.show()

# %%
basic_iter = iter(range(3))
print(basic_iter.__next__())
print(basic_iter.__next__())
print(basic_iter.__next__())
try:
    print(basic_iter.__next__())
except:
    print('woof')
else:
    print('meow')
# Out:
# 0
# 1
# 2
# woof

# %%
vid = imageio.get_reader('../../data/sim_video_clips/vid_wd2_brown.mp4','ffmpeg')
i = 0
for frame in vid:
    i+=1
print(i)
# Out:
# 4132

# %%
frame,steer,safety = next(iter(imitation_train_dataloader))

# %%
thing = 0
for X_train_batch,Y_train_batch,other_thing in imitation_train_dataloader:
    print('woof')
    thing += 1
print(thing)
# Out:
# woof
# woof
# woof
# woof
# woof
# woof
# woof
# woof
# woof
# woof
# woof
# woof
# woof
# woof
# woof
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\qtcc\OneDrive\Desktop\Senior Project\Pizzair\drone_control\testing_notebook.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/qtcc/OneDrive/Desktop/Senior%20Project/Pizzair/drone_control/testing_notebook.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> thing = 0
# ----> <a href='vscode-notebook-cell:/c%3A/Users/qtcc/OneDrive/Desktop/Senior%20Project/Pizzair/drone_control/testing_notebook.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> for X_train_batch,Y_train_batch,other_thing in imitation_train_dataloader:
#       <a href='vscode-notebook-cell:/c%3A/Users/qtcc/OneDrive/Desktop/Senior%20Project/Pizzair/drone_control/testing_notebook.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a>     print('woof')
# ...

# %%
print(frame.shape)
# Out:
# torch.Size([64, 720, 1280, 3])

# %%
print(len(np.load(label_dir+'label_steering_wd2_brown.npy')))
print(len(np.load(label_dir+'label_safety_wd2_brown.npy')))
# Out:
# 4132
# 4132

# %%
load_dir = '../../data/sim_video_clips/'
filename = 'vid_wd2_test.mp4'
vid = imageio.get_reader(load_dir + filename,'ffmpeg')
thing = vid.get_data(7)
thing = rgb2gray(thing)
plt.imshow(thing,cmap="gray")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 5
#       3 vid = imageio.get_reader(load_dir + filename,'ffmpeg')
#       4 thing = vid.get_data(7)
# ----> 5 thing = rgb2gray(thing)
#       6 plt.imshow(thing,cmap="gray")
#
# Cell In[9], line 8, in rgb2gray(rgb)
#       5 def rgb2gray(rgb):
#       6         ## little helper function for greyscale conversion
#       7         # grabs each channel
# ----> 8         r, g, b = rgb[:,:,:,0], rgb[:,:,:,1], rgb[:,:,:,2]
#       9         # normalizes independently
#      10         r = (r - np.min(r))/np.ptp(r)
#
# IndexError: too many indices for array: array is 3-dimensional, but 4 were indexed

# %%
# testing greyscale conversion 
import imageio
load_dir = '../../data/sim_video_clips/'
filename = 'vid_wd2_test.mp4'
vid = imageio.get_reader(load_dir + filename,'ffmpeg')
for frame in vid:
    frame = rgb2gray(frame)
    print(frame.shape)
# Out:
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)
# ...
